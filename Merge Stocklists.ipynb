# %%
import pandas as pd
import numpy as np

# %%
praneeth = pd.read_csv('stock_closing_data.csv', index_col=0)
john = pd.read_csv('stock_closing_data_john.csv', index_col=0)

# %%
len(praneeth.Company.append(john.Company).unique())
# Out:
# 1101

# %%
print(len(praneeth.Company))
print(len(john.Company))
stock_data = praneeth.append(john)
print(len(stock_data.Company))
# Out:
# 121140
# 76670
# 197810

# %%
len(stock_data.Company.unique())
# Out:
# 1101

# %%
stock_data
# Out:
#       Closing_Value Company          Date
# 0              7117     ANF  Dec 01, 2017
# 1                 0     ANF  Nov 30, 2017
# 2              6217     ANF  Oct 31, 2017
# 3              8413     ANF  Sep 30, 2017
# 4              7314     ANF  Aug 31, 2017
# 5                 0     ANF  Aug 30, 2017
# 6              0312     ANF  Jul 31, 2017
# 7               819     ANF  Jun 30, 2017
# 8              8712     ANF  May 31, 2017
# 9                 0     ANF  May 31, 2017
# 10             8513     ANF  Apr 30, 2017
# 11             5011     ANF  Mar 31, 2017
# 12                0     ANF  Mar 01, 2017
# 13             8311     ANF  Mar 01, 2017
# 14             2011     ANF  Feb 01, 2017
# 15             9111     ANF  Jan 01, 2017
# 16             8512     ANF  Dec 01, 2016
# 17                0     ANF  Nov 30, 2016
# 18             0014     ANF  Oct 31, 2016
# 19             4014     ANF  Sep 30, 2016
# 20             5115     ANF  Aug 31, 2016
# ...

# %%
stock_data.to_csv('stock_price_data.csv')
